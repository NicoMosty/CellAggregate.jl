# %% [markdown]
# # Adding Dependences

# %%
using DelimitedFiles
using Plots
include("../../init/extract_info.jl")
# Out:
# plot_compare (generic function with 1 method)

# %% [markdown]
# # Executing Functions -> (in init/extract_info.jl)

# %%
k = 0.3
corr_angle = 90
plot_compare(compare(k, corr_angle)[1], compare(k, corr_angle)[2])
