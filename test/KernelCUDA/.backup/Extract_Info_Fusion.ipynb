# %% [markdown]
# # Adding Dependences

# %%
using DelimitedFiles
using Plots
include("../../src/extract_info.jl")
# Out:
# plot_compare (generic function with 1 method)

# %% [markdown]
# # Executing Functions -> (in init/extract_info.jl)

# %%
k = 0.05
plot_compare(compare(k)[1], compare(k)[2])
